# %%
import pandas as pd

# %%
a = pd.read_csv(r"C:\Users\sd991188\OneDrive - GSK\workspace\practice\AccidentSeverity\Flask\data\final_accident_vehicle_dataset.csv")

# %%
b = a.head(1)

# %%
b.to_csv(r"C:\Users\sd991188\OneDrive - GSK\workspace\practice\AccidentSeverity\Flask\data\sample_data.csv", index=False)

# %%
b
# Out:
#   Accident_Index Age_Band_of_Driver  Age_of_Vehicle  \
# 0  200501BS00002            36 - 45             3.0
#
#           Driver_Home_Area_Type  Driver_IMD_Decile  Engine_Capacity_.CC.  \
# 0  Data missing or out of range                NaN                8268.0
#
#   Hit_Object_in_Carriageway Hit_Object_off_Carriageway  \
# 0                       NaN                        NaN
#
#   Journey_Purpose_of_Driver   Junction_Location  ...         Police_Force  \
# 0   Journey as part of work  Leaving roundabout  ...  Metropolitan Police
#
#   Road_Surface_Conditions         Road_Type Special_Conditions_at_Site  \
# 0                     Dry  Dual carriageway                        NaN
#
#   Speed_limit   Time Urban_or_Rural_Area  Weather_Conditions Year_y  \
# 0        30.0  17:36               Urban  Fine no high winds   2005
#
#    InScotland
# 0          No
#
# [1 rows x 57 columns]

# %%
b.T
# Out:
#                                                                                 0
# Accident_Index                                                      200501BS00002
# Age_Band_of_Driver                                                        36 - 45
# Age_of_Vehicle                                                                3.0
# Driver_Home_Area_Type                                Data missing or out of range
# Driver_IMD_Decile                                                             NaN
# Engine_Capacity_.CC.                                                       8268.0
# Hit_Object_in_Carriageway                                                     NaN
# Hit_Object_off_Carriageway                                                    NaN
# Journey_Purpose_of_Driver                                 Journey as part of work
# Junction_Location                                              Leaving roundabout
# ...
